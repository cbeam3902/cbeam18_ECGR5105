# %% [markdown]
# # Homework 0
# Christopher Beam
#
# 800927396
# ## Problem 1

# %%
# Setup
import torch
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
# Get dataset
df = pd.read_csv("../datasets/D3.csv")
df
# Out:
#           X1        X2        X3         Y
# 0   0.000000  3.440000  0.440000  4.387545
# 1   0.040404  0.134949  0.888485  2.679650
# 2   0.080808  0.829899  1.336970  2.968490
# 3   0.121212  1.524848  1.785455  3.254065
# 4   0.161616  2.219798  2.233939  3.536375
# ..       ...       ...       ...       ...
# 95  3.838384  1.460202  3.046061 -4.440595
# 96  3.878788  2.155152  3.494545 -4.458663
# 97  3.919192  2.850101  3.943030 -4.479995
# 98  3.959596  3.545051  0.391515 -3.304593
# 99  4.000000  0.240000  0.840000 -5.332455
#
# [100 rows x 4 columns]

# %%
# Linear Regression and Gradient_descent

def lineReg(X, Y, theta):
    pred = X.dot(theta)
    errors = np.square(np.subtract(pred,Y))
    return 1 / (2 * len(Y)) * np.sum(errors)

def gradDes(X, Y, theta, alpha, iterations):
    costArray = np.zeros(iterations)

    for i in range(iterations):
        pred = X.dot(theta)
        errors = np.subtract(pred, Y)
        delta = (alpha / len(Y)) * X.transpose().dot(errors)
        theta = theta - delta
        costArray[i] = lineReg(X, Y, theta)
    return theta, costArray

# %%
# Collect the Y Values
Y = df.values[:,3]
tempOnes = np.ones((len(Y),1))
iterations = 100

# %% [markdown]
# ### X1 and Y line fit

# %%
# Setup the X Values to match b + mx format [1, x]
X1_val = df.values[:,0]
X1_val = X1_val.reshape(len(Y), 1)
X1 = np.hstack((tempOnes, X1_val))

# %%
# Perform regression

learnSize = 20
learnRange = np.linspace(0.01, 0.1, learnSize, endpoint=True)
errorOut = []
thetaArray = []
lossArray = []
for learnRate in learnRange:
    theta_x1 = np.zeros(2)
    theta_x1, loss = gradDes(X1, Y, theta_x1, learnRate, iterations)
    lossArray.append(loss)
    thetaArray.append(theta_x1)
    errorOut.append(lineReg(X1, Y, theta_x1))

idx = np.argmin(errorOut)
print("Learn rate with lowest error is {:.1f}".format(learnRange[idx]))
print("Variables Found:\n\ttheta0 = {:.5f}\n\ttheta1 = {:.5f}".format(thetaArray[idx][0], thetaArray[idx][1]))
plt.scatter(X1[:,1], Y, color='red', marker= '+', label = 'Training Data')
plt.plot(X1[:,1], X1.dot(thetaArray[idx]), color='green', label='Linear Regression')

plt.title("X1 Line Fit")
plt.ylabel("Values")
plt.xlabel("X1")
plt.grid()
plt.legend()
plt.show()

plt.plot(range(iterations),lossArray[idx])
plt.title("X1 Loss")
plt.ylabel("Loss")
plt.xlabel("Iteration")
plt.grid()
plt.show()
# Out:
# Learn rate with lowest error is 0.1
# Variables Found:
# 	theta0 = 5.30705
# 	theta1 = -1.79668

# %% [markdown]
# ### X2 and Y line fit

# %%
# Setup the X Values to match b + mx format [1, x]
X2_val = df.values[:,1]
X2_val = X2_val.reshape(len(Y), 1)
X2 = np.hstack((tempOnes, X2_val))

# %%
# Perform regression

learnSize = 20
learnRange = np.linspace(0.01, 0.1, learnSize, endpoint=True)
errorOut = []
thetaArray = []
lossArray = []
for learnRate in learnRange:
    theta_x2 = np.zeros(2)
    theta_x2, loss = gradDes(X2, Y, theta_x2, learnRate, iterations)
    lossArray.append(loss)
    thetaArray.append(theta_x2)
    errorOut.append(lineReg(X2, Y, theta_x2))

idx = np.argmin(errorOut)
print("Learn rate with lowest error is {:.1f}".format(learnRange[idx]))
print("Variables Found:\n\ttheta0 = {:.5f}\n\ttheta1 = {:.5f}".format(thetaArray[idx][0], thetaArray[idx][1]))
plt.scatter(X2[:,1], Y, color='red', marker= '+', label = 'Training Data')
plt.plot(X2[:,1], X2.dot(thetaArray[idx]), color='green', label='Linear Regression')

plt.title("X2 Line Fit")
plt.ylabel("Values")
plt.xlabel("X2")
plt.grid()
plt.legend()
plt.show()

plt.plot(range(iterations),lossArray[idx])
plt.title("X2 Loss")
plt.ylabel("Loss")
plt.xlabel("Iteration")
plt.grid()
plt.show()
# Out:
# Learn rate with lowest error is 0.1
# Variables Found:
# 	theta0 = 0.68811
# 	theta1 = 0.57627

# %% [markdown]
# ### X3 and Y line fit

# %%
# Setup the X Values to match b + mx format [1, x]
X3_val = df.values[:,2]
X3_val = X3_val.reshape(len(Y), 1)
X3 = np.hstack((tempOnes, X3_val))

# %%
# Perform regression

learnSize = 20
learnRange = np.linspace(0.01, 0.1, learnSize, endpoint=True)
errorOut = []
thetaArray = []
lossArray = []
for learnRate in learnRange:
    theta_x3 = np.zeros(2)
    theta_x3, loss = gradDes(X3, Y, theta_x3, learnRate, iterations)
    lossArray.append(loss)
    thetaArray.append(theta_x3)
    errorOut.append(lineReg(X3, Y, theta_x3))

idx = np.argmin(errorOut)
print("Learn rate with lowest error is {:.1f}".format(learnRange[idx]))
print("Variables Found:\n\ttheta0 = {:.5f}\n\ttheta1 = {:.5f}".format(thetaArray[idx][0], thetaArray[idx][1]))
plt.scatter(X3[:,1], Y, color='red', marker= '+', label = 'Training Data')
plt.plot(X3[:,1], X3.dot(thetaArray[idx]), color='green', label='Linear Regression')

plt.title("X3 Line Fit")
plt.ylabel("Values")
plt.xlabel("X3")
plt.grid()
plt.legend()
plt.show()

plt.plot(range(iterations),lossArray[idx])
plt.title("X3 Loss")
plt.ylabel("Loss")
plt.xlabel("Iteration")
plt.grid()
plt.show()
# Out:
# Learn rate with lowest error is 0.1
# Variables Found:
# 	theta0 = 2.59759
# 	theta1 = -0.41219

# %% [markdown]
# ## Problem 2

# %%
# Combine all of the X values into one array
X = np.hstack((tempOnes, X1_val, X2_val, X3_val))

# %%
# Perform regression

learnSize = 20
learnRange = np.linspace(0.01, 0.1, learnSize, endpoint=True)
errorOut = []
thetaArray = []
lossArray = []
for learnRate in learnRange:
    theta = np.zeros(4)
    theta, loss = gradDes(X, Y, theta, learnRate, iterations)
    lossArray.append(loss)
    thetaArray.append(theta)
    errorOut.append(lineReg(X, Y, theta))

idx = np.argmin(errorOut)
print("Learn rate with lowest error is {:.1f}".format(learnRange[idx]))
print("Variables Found:\n\ttheta0 = {:.5f}\n\ttheta1 = {:.5f}\n\ttheta2 = {:.5f}\n\ttheta3 = {:.5f}".format(thetaArray[idx][0], thetaArray[idx][1], thetaArray[idx][2], thetaArray[idx][3]))

plt.plot(range(iterations),lossArray[idx])
plt.title("X Loss")
plt.ylabel("Loss")
plt.xlabel("Iteration")
plt.grid()
plt.show()
# Out:
# Learn rate with lowest error is 0.1
# Variables Found:
# 	theta0 = 3.40790
# 	theta1 = -1.73442
# 	theta2 = 0.84756
# 	theta3 = 0.01381

# %%
# Predictions

print("Predictions of y for values (1,1,1), (2,0,4), and (3,2,1):")
new_x = np.array([[1,1,1,1],[1,2,0,4],[1,3,2,1]])
est_y = new_x.dot(thetaArray[idx])
print("y at (1,1,1) = ", est_y[0])
print("y at (2,0,4) = ", est_y[1])
print("y at (3,1,1) = ", est_y[2])
# Out:
# Predictions of y for values (1,1,1), (2,0,4), and (3,2,1):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 5
#       3 print("Predictions of y for values (1,1,1), (2,0,4), and (3,2,1):")
#       4 new_x = np.array([[1,1,1],[2,0,4],[3,2,1]])
# ----> 5 est_y = new_x.dot(thetaArray[idx])
#       6 print("y at (1,1,1) = ", est_y[0])
#       7 print("y at (2,0,4) = ", est_y[1])
#
# ValueError: shapes (3,3) and (4,) not aligned: 3 (dim 1) != 4 (dim 0)

# %%
thetaArray[idx]
# Out:
# array([ 3.40790315, -1.73442481,  0.84756123,  0.01381493])
